# %% [markdown]
# # Visualización con matplotlib

# %% [markdown]
# ## ¿Qué es matplotlib?

# %% [markdown]
# * Librería para visualización en Python
# * Diferentes formas de usarla: interfaz `pyplot` y orientada a objetos

# %% [markdown]
# Activar el modo *inline* - las figuras aparecerán automáticamente incrustadas en el notebook.

# %%
# %matplotlib inline

# %% [markdown]
# Importamos los paquetes necesarios:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# La biblioteca matplotlib es muy completa y es difícil conocer las posibilidades que trae consigo mirándola por primera vez. Es recomendable tener a mano la documentación y la galería:

# %%
from IPython.display import HTML
HTML('<iframe src="http://matplotlib.org/gallery.html" width="800" height="600"></iframe>')
# Out:
# <iframe src="http://matplotlib.org/gallery.html" width="800" height="600"></iframe>

# %% [markdown]
# Si hacemos clic en cualquiera de las imágenes, accedemos al código fuente que la ha generado:

# %%
HTML('<iframe src="http://matplotlib.org/examples/pylab_examples/annotation_demo.html" width="800" height="600"></iframe>')
# Out:
# <iframe src="http://matplotlib.org/examples/pylab_examples/annotation_demo.html" width="800" height="600"></iframe>

# %% [markdown]
# ## Interfaz pyplot

# %% [markdown]
# ### Función `plot`

# %% [markdown]
# La interfaz `pyplot` proporciona una serie de funciones que operan sobre un *estado global* - es decir, nosotros no especificamos sobre qué gráfica o ejes estamos actuando. Es una forma rápida y cómoda de crear gráficas pero perdemos parte del control.

# %% [markdown]
# El paquete `pyplot` se suele importar bajo el alias `plt`, de modo que todas las funciones se acceden a través de `plt.<funcion>`. La función más básica es la función `plot`:

# %%
plt.plot([0, 0.1, 0.2, 0.5,0.6], [1, -1, 0, 3, -1])

# %% [markdown]
# La función `plot` recibe una sola lista (si queremos especificar los valores *y*) o dos listas (si especificamos *x* e *y*). Naturalmente si especificamos dos listas ambas tienen que tener la misma longitud.

# %% [markdown]
# La tarea más habitual a la hora de trabajar con matplotlib es representar una función. Lo que tendremos que hacer es definir un dominio y evaluarla en dicho dominio. Por ejemplo:

# %% [markdown]
# $$f(x) = e^{-x^2}$$

# %%
def f(x):
    return np.exp(-x ** 2)

# %% [markdown]
# Definimos el dominio con la función `np.linspace`, que crea un vector de puntos equiespaciados:

# %%
x = np.linspace(-1, 5, num=30)

# %%
x
# Out:
# array([-1.        , -0.79310345, -0.5862069 , -0.37931034, -0.17241379,
#         0.03448276,  0.24137931,  0.44827586,  0.65517241,  0.86206897,
#         1.06896552,  1.27586207,  1.48275862,  1.68965517,  1.89655172,
#         2.10344828,  2.31034483,  2.51724138,  2.72413793,  2.93103448,
#         3.13793103,  3.34482759,  3.55172414,  3.75862069,  3.96551724,
#         4.17241379,  4.37931034,  4.5862069 ,  4.79310345,  5.        ])

# %% [markdown]
# Y representamos la función:

# %%
plt.plot(x, f(x))

# %%
#, label="Función f(x)")
plt.plot(x, f(x))
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")

# %%
#, label="Función f(x)")
plt.plot(x, f(x))
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")
plt.legend("f(x)")
plt.title("Función $f(x)$")

# %% [markdown]
# Notamos varias cosas:
#
# * Con diversas llamadas a funciones dentro de `plt.` se actualiza el gráfico *actual*. Esa es la forma de trabajar con la interfaz pyplot.
# * Podemos añadir etiquetas, y escribir $\LaTeX$ en ellas. Tan solo hay que encerrarlo entre signos de dólar $$.

# %% [markdown]
# ### Personalización

# %% [markdown]
# La función `plot` acepta una serie de argumentos para personalizar el aspecto de la función. Con una letra podemos especificar el color, y con un símbolo el tipo de línea.

# %%
plt.plot(x, f(x), 'ro')

# %%
plt.plot(x, 1 - f(x), 'g--')

# %%
plt.plot(x, f(x), 'ro')
plt.plot(x, 1 - f(x), 'g--')

# %%
plt.plot(x, f(x), 'ro')
plt.plot(x, 1 - f(x), 'g--')
plt.grid(True)

# %% [markdown]
# Esto en realidad son códigos abreviados, que se corresponden con argumentos de la función `plot`:

# %%
plt.plot(x, f(x), color='red', linestyle='', marker='o')
plt.plot(x, 1 - f(x), c='y', ls='--')
plt.grid(True)

# %% [markdown]
# La lista de posibles argumentos y abreviaturas está disponible en la documentación de la función `plot` http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot.

# %% [markdown]
# Verificamos el estilo de presentación de nuestros gráficos

# %%
 print(plt.style.available)
# Out:
# ['seaborn-ticks', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-pastel', 'seaborn-deep', 'grayscale', 'seaborn-talk', 'seaborn-whitegrid', 'seaborn-notebook', 'seaborn-paper', 'seaborn-poster', 'dark_background', 'classic', 'fivethirtyeight', 'seaborn-dark', 'ggplot', 'seaborn-dark-palette', 'bmh', 'seaborn-darkgrid', 'seaborn-white', 'seaborn-muted']

# %% [markdown]
# Usaremos el estilo ggplot

# %%
plt.style.use('ggplot')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('ggplot')
plt.plot([-1, 2, -3, 4], [1, 4, -9, 16])
plt.show()

# %%
plt.style.use('ggplot')
plt.plot(np.sort([-1, 2, -3, 4]), np.sort([1, 4, -9, 16]))
plt.show()

# %%
#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot(x, f(x))
plt.plot(x, 1 - f(x))

# %%
plt.style.use('dark_background')
plt.plot(x, f(x))
plt.plot(x, 1 - f(x))

# %% [markdown]
# ### Otro tipo de gráficas

# %% [markdown]
# ### Scaterplots o de dispersión de puntos

# %% [markdown]
# La función `scatter` muestra una nube de puntos, con posibilidad de variar también el tamaño y el color.

# %%
N = 100
x = np.random.randn(N)
y = np.random.randn(N)

x,y
# Out:
# (array([-1.19381319,  1.24853002, -0.90261682, -0.5776588 , -0.10066027,
#          1.5616081 , -0.87544388,  1.04481564,  0.9932887 ,  1.22072108,
#         -0.61609886,  0.83399761,  0.02673537,  0.48282405, -0.42029773,
#         -1.93790485,  0.20108302,  0.79418246,  0.92531795,  0.36960825,
#         -0.35485499, -0.74751564,  0.82279442,  0.90886289, -0.03888466,
#          0.25910004,  0.18758805, -0.49348379,  0.88586352,  1.4649944 ,
#         -1.66663443,  0.52696358,  0.41632615, -0.1618956 , -0.97830285,
#          1.74594054, -0.17713836,  1.7432117 ,  0.88272844,  0.05907441,
#         -0.17144118,  0.18642971,  0.53029464,  0.18266095, -0.40625161,
#          1.09976599,  1.6640582 , -0.02132687,  0.15774939,  0.75137569,
#         -0.33873205, -2.09523807,  0.15459605,  1.07791925, -1.29613423,
#         -2.16076342,  0.59604093, -1.00489887, -1.40370466, -1.18143733,
#          0.32991294,  1.30587754, -1.36754664,  0.21055925,  0.29578764,
#          0.20982893,  0.63042872, -0.02455845, -1.4305252 ,  0.23666415,
#          1.04410588, -0.26060178, -0.82675987,  0.80698009, -0.53479314,
#         -0.2559659 ,  0.83382849,  0.57448423,  2.37187905, -0.39351086,
#          1.13637694, -0.86879605,  2.11869263,  1.45685199,  0.77098763,
#         -1.33814898,  0.54312017, -0.68831502,  0.73762604,  0.17259248,
#         -0.16926624,  1.95928715, -0.82668918, -0.51068838,  0.74179463,
#         -0.57385475, -0.53720334,  0.94060203,  0.92606339,  1.96016478]),
#  array([ 0.63269224,  1.09405975,  0.05186718, -0.21852001,  0.19411577,
#         -0.53148017,  1.16619938, -0.78678129,  0.80661012,  2.08162837,
#         -0.06469027,  1.29435774,  0.38684811,  0.10040212,  0.85619114,
#          0.68806002,  0.52523648,  0.04365168, -0.6681857 ,  1.6881172 ,
#          0.30829532,  0.86188381,  2.15183679,  1.02113553, -1.02175447,
#         -1.08771869,  2.03514004, -1.64898886, -0.70763782,  0.69675916,
#          0.31843413, -1.45017604,  0.12621878,  2.02812148, -0.86740345,
#         -1.54986422, -0.64263353,  0.12736123, -0.40208517,  1.03080809,
#          1.17480618,  1.37745572,  0.96065869, -0.22998182, -0.53351387,
#          0.060924  ,  1.04136667, -0.86282978,  0.32846248,  1.03823021,
#          1.14706372,  0.63825446, -1.07576564, -0.22854319, -0.08197072,
#         -1.88048338, -0.88737603,  1.42678085, -0.44284426, -1.48128753,
#          0.49047079,  1.18570875, -1.75644094, -0.17857027, -0.87638718,
#         -0.80809249, -0.97504571,  0.24224455, -0.08987694,  1.39021076,
#         -1.04628649,  1.50728454,  0.02938804,  0.10883985, -0.81561127,
#          0.42645469,  1.38526008, -0.88446331,  1.12822123, -0.68785403,
#         -0.45828099,  0.26307009, -0.03774913, -0.1021778 , -0.01413351,
#          2.02712233,  0.1583141 , -1.08954514, -1.22006172, -0.29239965,
#          1.89685522,  2.57127252,  0.9511683 , -1.22293538, -0.92514544,
#         -1.18698546, -0.91204022, -2.39446226,  0.56694864, -0.61807927]))

# %%
plt.style.use('ggplot')
plt.scatter(x, y)

# %% [markdown]
# Con `s` y `c` podemos modificar el tamaño y el color respectivamente. Para el color, a cada valor numérico se le asigna un color a través de un *mapa de colores*; ese mapa se puede cambiar con el argumento `cmap`. Esa correspondencia se puede visualizar llamando a la función `colorbar`.

# %%
s =50 * np.random.randn(N)
c = 50*np.random.randn(N)

s,c
# Out:
# (array([  93.15434766,   20.60960697,   36.3298283 ,  -90.24620238,
#          -25.06834684,  -60.84657003,  -82.14812225,   29.02488609,
#          143.43370178,   91.28891   ,  108.26968628,   70.0598758 ,
#          131.50097339,   78.19626939,   33.67997566,   92.19088853,
#           92.85338587,   74.31928879,   95.1522147 ,  116.25845494,
#           63.01949261,  100.00273702,   70.30826704,  119.71958828])]

# %%
np.shape(data_to_plot)
# Out:
# (3, 200)

# %%
np.size(data_to_plot)
# Out:
# 600

# %%
# Create the boxplot
bp = plt.boxplot(data_to_plot)

# %%
"""
=================================
Box plots with custom fill colors
=================================

This plot illustrates how to create two types of box plots
(rectangular and notched), and how to fill them with custom
colors by accessing the properties of the artists of the
box plots. Additionally, the ``labels`` parameter is used to
provide x-tick labels for each sample.

A good general reference on boxplots and their history can be found
here: http://vita.had.co.nz/papers/boxplots.pdf

"""
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(123)
all_data = [np.random.normal(0, std, 100) for std in range(1, 4)]
all_data
# Out:
# [array([-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025,
#          1.65143654, -2.42667924, -0.42891263,  1.26593626, -0.8667404 ,
#         -0.67888615, -0.09470897,  1.49138963, -0.638902  , -0.44398196,
#         -0.43435128,  2.20593008,  2.18678609,  1.0040539 ,  0.3861864 ,
#          0.73736858,  1.49073203, -0.93583387,  1.17582904, -1.25388067,
#         -0.6377515 ,  0.9071052 , -1.4286807 , -0.14006872, -0.8617549 ,
#         -0.25561937, -2.79858911, -1.7715331 , -0.69987723,  0.92746243,
#         -0.17363568,  0.00284592,  0.68822271, -0.87953634,  0.28362732,
#         -0.80536652, -1.72766949, -0.39089979,  0.57380586,  0.33858905,
#         -0.01183049,  2.39236527,  0.41291216,  0.97873601,  2.23814334,
#         -1.29408532, -1.03878821,  1.74371223, -0.79806274,  0.02968323,
#          1.06931597,  0.89070639,  1.75488618,  1.49564414,  1.06939267,
#         -0.77270871,  0.79486267,  0.31427199, -1.32626546,  1.41729905,
#          0.80723653,  0.04549008, -0.23309206, -1.19830114,  0.19952407,
#          0.46843912, -0.83115498,  1.16220405, -1.09720305, -2.12310035,
#          1.03972709, -0.40336604, -0.12602959, -0.83751672, -1.60596276,
#          1.25523737, -0.68886898,  1.66095249,  0.80730819, -0.31475815,
#         -1.0859024 , -0.73246199, -1.21252313,  2.08711336,  0.16444123,
#          1.15020554, -1.26735205,  0.18103513,  1.17786194, -0.33501076,
#          1.03111446, -1.08456791, -1.36347154,  0.37940061, -0.37917643]),
#  array([ 1.28410938, -3.95577586,  1.42452927,  5.19660785, -0.04925196,
#          0.06828426,  0.35909897, -3.72395142,  0.85229328, -3.21081949,
#         -0.8553592 ,  2.4857391 , -1.47043391,  1.00249798,  2.02547811,
#          0.55748171, -2.74189694, -0.66495055,  3.91882268, -4.05009153,
#         -0.55157203, -1.10421614,  0.24149473,  1.49643123,  3.21738194,
#         -0.54046478,  1.62468266,  0.99948029,  0.9486946 , -1.12784786,
#         -1.99464294, -2.20008623, -1.51287442,  0.64337315,  1.52189879,
#          0.6469377 , -1.09791019,  3.61194022,  3.03773125, -0.70800023,
#         -1.64686281,  0.26042991,  2.53459729,  0.66552995,  1.11309741,
#         -0.42416024,  0.91254179,  3.0890889 , -0.47933756,  0.28661547,
#          0.50763295,  0.56745071, -2.82377775, -3.75373731, -2.03931014,
#          0.33588459,  1.10771233, -1.06134912,  2.75451497, -0.28635195,
#          0.040632  , -0.38792774,  0.26805359,  1.40894815,  1.33130688,
#         -1.79684588,  3.04732755, -2.19005291,  0.15845403, -0.54879315,
#         -2.09798335, -0.15024118, -1.48162755,  0.14581449,  0.80617192,
#          2.94385874,  0.61476844, -1.22245068, -0.78323962,  0.27995621,
#          0.18692166,  2.91917854,  2.79070586, -0.71787185, -1.09728426,
#         -5.11410921, -1.09784083, -1.95611541, -0.70964892,  0.78316848,
#          0.35438466, -0.05993601,  0.39916422, -0.25223555,  0.39403787,
#         -6.46211002, -0.53858698, -0.22170144, -0.68252343, -0.43589252]),
#  array([ 2.10993035, -1.79431599,  6.6021063 ,  2.06489079, -0.01892175,
#         -0.61998691, -0.25956686, -2.74592121, -0.28560762,  0.83605055,
#          1.73862485,  1.73906934, -0.82463264, -4.24824676, -2.00730788,
#          4.83657913,  2.68817494,  1.10885876, -2.28388273,  0.01093546,
#         -3.76700606, -1.65581063, -0.73561003, -1.0849198 ,  2.86980579,
#         -4.25617774, -2.59629681, -4.12406391, -3.71205964,  0.37216769,
#         -4.8013216 ,  2.26160634, -0.74044733,  0.206365  ,  0.96773021,
#         -1.30249956,  3.09743915, -0.58302818,  1.78221077, -0.59733715,
#          0.87262316,  0.83898801,  0.74990982, -2.92292355,  1.30762731,
#         -0.95687097,  1.89146409, -6.45748033, -4.39534867,  1.09033669,
#          5.58878276,  2.50517624, -2.0473528 , -5.07615725,  2.22805866,
#         -0.24174967,  1.77211265,  0.34589617,  0.08892878,  8.87587634,
#         -0.01838988, -0.47773563, -0.36434603, -1.75061015,  2.97039868,
#         -1.061263  ,  1.90782812,  0.85380909,  3.65695759,  1.26053879,
#         -3.64015434, -3.97946336,  4.22510744, -1.82613241, -3.96180774,
#         -2.0088558 ,  3.79387586, -4.260639  , -2.59948561, -2.00042253,
#         -3.75356962, -3.55298202, -4.55432393, -1.38356224, -1.0647265 ,
#         -2.04761446, -4.96109352,  3.76000784, -3.98723649,  0.83410114,
#         -3.22429978,  2.0049506 ,  2.86749707, -2.63284076, -5.77114719,
#          2.08736196,  5.62740164,  1.24708362,  0.48163326,  2.45928183])]

# %%
np.shape(all_data)
# Out:
# (3, 100)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 5)) #Figsize, width=8 pulgadas, heigth=5 pulgadas

# %%
# rectangular box plot
bplot1 = axes[0].boxplot(all_data,
                         vert=True,   # vertical box aligmnent
                         patch_artist=True)   # fill with color

bplot2 = axes[1].boxplot(all_data,
                         notch=True,  # notch shape
                         vert=True,   # vertical box aligmnent
                         patch_artist=True)   # fill with color

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 5)) #Figsize, width=8 inches, heigth=5
# rectangular box plot
bplot1 = axes[0].boxplot(all_data,
                         vert=True,   # vertical box aligmnent
                         patch_artist=True)   # fill with color

# notch shape box plot
bplot2 = axes[1].boxplot(all_data,
                         notch=True,  # notch shape
                         vert=True,   # vertical box aligmnent
                         patch_artist=True)   # fill with color

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y+1 for y in range(len(all_data))], )
    ax.set_xlabel('xlabel')
    ax.set_ylabel('ylabel')

# add x-tick labels
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])

plt.show()

# %% [markdown]
# ### Heat Maps

# %%
# Generate Data
data = np.random.rand(10,6)
data
# Out:
# array([[ 0.23268638,  0.74669763,  0.77776902,  0.20040131,  0.82057422,
#          0.46493485],
#        [ 0.77976666,  0.23747822,  0.33258027,  0.95369712,  0.65781507,
#          0.77287783],
#        [ 0.68837434,  0.20430412,  0.47068875,  0.80896387,  0.67503513,
#          0.00602789],
#        [ 0.08740774,  0.34679472,  0.94436554,  0.49119048,  0.27017627,
#          0.36042372],
#        [ 0.21065263,  0.42120006,  0.21803544,  0.84575251,  0.4562706 ,
#          0.27980202],
#        [ 0.93289165,  0.31435135,  0.90971466,  0.04341809,  0.70711506,
#          0.48388904],
#        [ 0.44422106,  0.03632334,  0.04068319,  0.33275362,  0.94711954,
#          0.61765998],
#        [ 0.36887484,  0.61197704,  0.20613154,  0.16506644,  0.36181727,
#          0.86335335],
#        [ 0.50940173,  0.29690152,  0.95025163,  0.81596609,  0.32297394,
#          0.97209825],
#        [ 0.9873511 ,  0.40866013,  0.6559231 ,  0.4056532 ,  0.25734811,
#          0.08265268]])

# %%
np.shape(data)
# Out:
# (10, 6)

# %%
rows = list('ZYXWVUTSRQ')
columns = list('ABCDEF')

# %%
plt.pcolor(data)
plt.show()

# %%
np.arange(0,6)+0.5
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5])

# %%
np.arange(0,10)+0.5
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5])

# %%
# Add Row/Column Labels
plt.pcolor(data)
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()
plt.close()

# %%
# Change color map
plt.pcolor(data,cmap=plt.cm.Oranges)
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %%
data
# Out:
# array([[ 0.23268638,  0.74669763,  0.77776902,  0.20040131,  0.82057422,
#          0.46493485],
#        [ 0.77976666,  0.23747822,  0.33258027,  0.95369712,  0.65781507,
#          0.77287783],
#        [ 0.68837434,  0.20430412,  0.47068875,  0.80896387,  0.67503513,
#          0.00602789],
#        [ 0.08740774,  0.34679472,  0.94436554,  0.49119048,  0.27017627,
#          0.36042372],
#        [ 0.21065263,  0.42120006,  0.21803544,  0.84575251,  0.4562706 ,
#          0.27980202],
#        [ 0.93289165,  0.31435135,  0.90971466,  0.04341809,  0.70711506,
#          0.48388904],
#        [ 0.44422106,  0.03632334,  0.04068319,  0.33275362,  0.94711954,
#          0.61765998],
#        [ 0.36887484,  0.61197704,  0.20613154,  0.16506644,  0.36181727,
#          0.86335335],
#        [ 0.50940173,  0.29690152,  0.95025163,  0.81596609,  0.32297394,
#          0.97209825],
#        [ 0.9873511 ,  0.40866013,  0.6559231 ,  0.4056532 ,  0.25734811,
#          0.08265268]])

# %% [markdown]
# ### Scatter Matrix

# %%
data=np.random.randn(1000, 4)
data.shape
# Out:
# (1000, 4)

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

spm = pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='hist')

# %%
spm = pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #kernel desnsity estimation

# %% [markdown]
# ### Trellis Plot

# %%
import pandas as pd
tips_data = pd.read_csv('tips.csv')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_data.sort_values(['total_bill','tip'],ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4
# 112       38.07   4.00    Male     No   Sun  Dinner     3
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4
# 238       35.83   4.67  Female     No   Sat  Dinner     3
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 180       34.65   3.68    Male    Yes   Sun  Dinner     4
# 179       34.63   3.55    Male    Yes   Sun  Dinner     2
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 173       31.85   3.18    Male    Yes   Sun  Dinner     2
# 167       31.71   4.50    Male     No   Sun  Dinner     4
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# ..          ...    ...     ...    ...   ...     ...   ...
# 117       10.65   1.50  Female     No  Thur   Lunch     2
# 169       10.63   2.00  Female    Yes   Sat  Dinner     2
# 168       10.59   1.61  Female    Yes   Sat  Dinner     2
# 75        10.51   1.25    Male     No   Sat  Dinner     2
# 196       10.34   2.00    Male    Yes  Thur   Lunch     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 136       10.33   2.00  Female     No  Thur   Lunch     2
# 16        10.33   1.67  Female     No   Sun  Dinner     3
# 51        10.29   2.60  Female     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 226       10.09   2.00  Female    Yes   Fri   Lunch     2
# 82        10.07   1.83  Female     No  Thur   Lunch     1
# 235       10.07   1.25    Male     No   Sat  Dinner     2
# 53         9.94   1.56    Male     No   Sun  Dinner     2
# 148        9.78   1.73    Male     No  Thur   Lunch     2
# 43         9.68   1.32    Male     No   Sun  Dinner     2
# 178        9.60   4.00  Female    Yes   Sun  Dinner     2
# 30         9.55   1.45    Male     No   Sat  Dinner     2
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 222        8.58   1.92    Male    Yes   Fri   Lunch     1
# 126        8.52   1.48    Male     No  Thur   Lunch     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 145        8.35   1.50  Female     No  Thur   Lunch     2
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2
# 195        7.56   1.44    Male     No  Thur   Lunch     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-ed9806ce3570> in <module>()
# ----> 1 import seaborn as sns
#
# ImportError: No module named 'seaborn'

# %%
sns.set(style="darkgrid")

tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "total_bill", color="steelblue", bins=bins, lw=0)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
#import pandas.tools.rplot as rplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\__init__.py in <module>()
#      15 try:
# ---> 16     from . import multiarray
#      17 except ImportError:
#
# ImportError: DLL load failed: No se puede encontrar el módulo especificado.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-878525855d3c> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2
#       3 import matplotlib.pyplot as plt
#       4 #import pandas.tools.rplot as rplot
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-105> in matplotlib(self, line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    2935         """
#    2936         from IPython.core import pylabtools as pt
# -> 2937         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2938
#    2939         if gui != 'inline':
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in find_gui_and_backend(gui, gui_select)
#     270     """
#     271
# --> 272     import matplotlib
#     273
#     274     if gui and gui != 'auto':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in <module>()
#     120 # cbook must import matplotlib only within function
#     121 # definitions, so it is safe to import from it here.
# --> 122 from matplotlib.cbook import is_string_like, mplDeprecation, dedent, get_label
#     123 from matplotlib.compat import subprocess
#     124 from matplotlib.rcsetup import (defaultParams,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook.py in <module>()
#      30 from weakref import ref, WeakKeyDictionary
#      31
# ---> 32 import numpy as np
#      33 import numpy.ma as ma
#      34
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\__init__.py in <module>()
#     140         return loader(*packages, **options)
#     141
# --> 142     from . import add_newdocs
#     143     __all__ = ['add_newdocs',
#     144                'ModuleDeprecationWarning',
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\add_newdocs.py in <module>()
#      11 from __future__ import division, absolute_import, print_function
#      12
# ---> 13 from numpy.lib import add_newdoc
#      14
#      15 ###############################################################################
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\__init__.py in <module>()
#       6 from numpy.version import version as __version__
#       7
# ----> 8 from .type_check import *
#       9 from .index_tricks import *
#      10 from .function_base import *
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\type_check.py in <module>()
#       9            'common_type']
#      10
# ---> 11 import numpy.core.numeric as _nx
#      12 from numpy.core.numeric import asarray, asanyarray, array, isnan, \
#      13                 obj2sctype, zeros
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\__init__.py in <module>()
#      22 files not under version control).  Otherwise reinstall numpy.
#      23 """
# ---> 24     raise ImportError(msg)
#      25
#      26 for envkey in env_added:
#
# ImportError:
# Importing the multiarray numpy extension module failed.  Most
# likely you are trying to import a failed build of numpy.
# If you're working with a numpy git repo, try `git clean -xdf` (removes all
# files not under version control).  Otherwise reinstall numpy.

# %%
plt.figure()
plot=rplot.RPlot(tips_data, x='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomHistogram())
plot.render(plt.gcf())

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomDensity())
plot.render(plt.gcf())

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomScatter())
plot.add(rplot.GeomPolyFit(degree=2))
plot.render(plt.gcf())

# %% [markdown]
# ## Interfaz orientada a objetos

# %%
x
# Out:
# array([ 0.02306789,  0.38650176, -0.63824241, -0.11213217,  0.80811881,
#        -0.81764842, -1.56293824, -0.39995675, -0.60907107, -1.1965418 ,
#        -1.57429545,  0.18784055, -0.56171904,  0.98100756,  0.59336432,
#        -0.54638957,  0.49853086,  1.28502457,  0.38583633,  2.10485624,
#         0.59789658, -1.29393582, -0.76949877,  0.20740409,  0.20137551,
#         0.8474645 ,  1.04236004,  1.45168782, -0.75177591, -0.63747593,
#        -0.28513417,  0.66040723, -0.61832952, -1.50707953,  1.10903605,
#         0.81000485,  0.17151204,  0.09888702, -0.100009  , -0.07660113,
#        -0.17046788,  1.18567236, -0.94627264, -0.15299767, -0.62032489,
#        -0.19661874, -1.16876789,  1.35118326,  1.07990305,  1.04382138,
#        -0.07922217, -0.5528521 ,  0.11432616,  0.37781415, -0.94782318,
#         1.29959656,  0.59524208, -0.17262311, -2.00419424,  0.21076421,
#        -1.99069583,  0.01154112, -0.63281067,  0.51445833, -0.62736938,
#         1.58878849, -0.15338532,  1.33858865, -1.01052594,  0.02742501,
#        -1.61343822,  0.75623951,  0.33509423, -0.1586924 , -0.24754279,
#        -1.43735457, -0.06157359,  0.89395911,  0.93711504,  0.17402296,
#         1.26264365,  0.20984863,  1.05126577, -0.68916927, -0.36484145,
#        -1.42915723,  1.01309317, -0.99736237,  0.63347973,  0.69892338,
#         1.54866768, -0.61184399,  0.43143544,  2.31299755, -0.78338171,
#        -0.33837509, -0.1357091 ,  0.76893817,  0.14729126,  1.43549011])

# %%
f(x)
# Out:
# array([ 0.99946801,  0.86123867,  0.66540901,  0.9875051 ,  0.52045284,
#         0.51245164,  0.08691923,  0.85217327,  0.69006632,  0.23889951,
#         0.08387681,  0.96533115,  0.72940344,  0.38198428,  0.703223  ,
#         0.74189945,  0.77994411,  0.19180268,  0.86168141,  0.01190949,
#         0.69943646,  0.18744498,  0.55314873,  0.95789563,  0.96025914,
#         0.48763111,  0.33739044,  0.1215539 ,  0.56826523,  0.66605998,
#         0.9219157 ,  0.64652869,  0.68226891,  0.10317913,  0.29230399,
#         0.51886692,  0.97101207,  0.99026901,  0.99004805,  0.99414945,
#         0.97135886,  0.2451662 ,  0.40843116,  0.97686356,  0.68058472,
#         0.96207879,  0.25512073,  0.16110545,  0.31155151,  0.33636343,
#         0.9937435 ,  0.73664775,  0.98701458,  0.86697639,  0.4072334 ,
#         0.18471315,  0.70165522,  0.97064087,  0.0180106 ,  0.95655064,
#         0.01900848,  0.99986681,  0.67001891,  0.76746119,  0.67462902,
#         0.08011847,  0.97674755,  0.16665665,  0.36017593,  0.99924815,
#         0.07403755,  0.56445298,  0.89378668,  0.97513118,  0.94056226,
#         0.12669303,  0.99621587,  0.44970526,  0.4155366 ,  0.97016997,
#         0.20305691,  0.95691908,  0.33115799,  0.62191349,  0.87536942,
#         0.12970529,  0.35830963,  0.36982266,  0.6694515 ,  0.61354977,
#         0.0908658 ,  0.68773405,  0.83016024,  0.00474835,  0.54135128,
#         0.89181399,  0.9817516 ,  0.553626  ,  0.97853892,  0.12737346])

# %%
fig, axes = plt.subplots()

# %%
fig, axes = plt.subplots()
axes.plot(x, f(x), 'ro', label="Función F(x)")

# %%
fig, axes = plt.subplots()
axes.plot(x, f(x), 'ro', label="Función F(x)")
axes.set_xlim(-2, 4)
axes.set_ylim(-1, 2)
# Out:
# (-1, 2)

# %%
fig, axes = plt.subplots()
axes.plot(x, f(x), 'ro', label="Función F(x)")
axes.set_xlim(-2, 4)
axes.set_ylim(-1, 2)

fig.savefig("grafica1.png")

# %%
fig, axes = plt.subplots(1, 2)

# %%
import pandas as pd
a = pd.Series(x)

# %%
b = a.order()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':

# %%
fb = f(b)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)

axes[0].plot(b, f(b), color="blue")
axes[0].set_xlabel("Eje x")

axes[1].plot(b, -f(b), 'r')
axes[1].set_xlabel("Eje x de la gráfica derecha")

# %%
x = np.random.randn(100)
y = np.random.randn(100)

s = 200 * np.random.randn(100)
c = 200*np.random.randn(100)

plt.scatter(x, y, s, c, cmap=plt.cm.BrBG_r)

# %% [markdown]
# ## Referencias

# %% [markdown]
# * Documentación pyplot http://matplotlib.org/api/pyplot_api.html
# * Tutorial de matplotlib en español http://pybonacci.wordpress.com/tag/tutorial-matplotlib-pyplot/
# * Referencia rápida de matplotlib http://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#quick-references
